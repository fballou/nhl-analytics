# %%
import pandas as pd
import numpy as np
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import json
import re
import random
import lxml

# %% [markdown]
# ## Context ##
#
# As an avid fan, I love following my team, but also players from all other teams. However, advanced stats are not only hard to come by, but they're quite hard to read. I want to create a way to quantify the data to grade and rank players across numerous metrics, to look beyond goals and points. There are many models out there like the WAR model, but those are readily available to the public. My goal with this projet is to create something similiar, but publish it for all fans to enjoy and learn.

# %% [markdown]
# ### Public Sources to Use ###
# https://www.naturalstattrick.com/
#
# https://moneypuck.com/stats.htm
#
# https://hockeyviz.com/team/S.J/2425

# %%
url = "https://www.naturalstattrick.com/playerteams.php?fromseason=20242025&thruseason=20242025&stype=2&sit=5v5&score=all&stdoi=oi&rate=n&team=ALL&pos=S&loc=B&toi=0&gpfilt=none&fd=&td=&tgp=410&lines=single&draftteam=ALL"
tables = pd.read_html(url)
df = tables[0]

# %%
df.head()
# Out:
#    Unnamed: 0         Player Team Position  GP          TOI    CF    CA  \
# 0           1     Ryan Suter  STL        D  82  1396.866667  1185  1394
# 1           2    Brent Burns  CAR        D  82  1293.400000  1590  1159
# 2           3    Corey Perry  EDM        R  80   828.516667   881   739
# 3           4  Alex Ovechkin  WSH        L  65   822.200000   815   859
# 4           5  Evgeni Malkin  PIT        C  68   981.550000   984   992
#
#      CF%    FF  ...    PDO  Off. Zone Starts  Neu. Zone Starts  \
# 0  45.95   823  ...  1.017               147               312
# 1  57.84  1119  ...  0.982               227               245
# 2  54.38   611  ...  1.013               183               141
# 3  48.69   596  ...  1.045               242               185
# 4  49.80   690  ...  0.990               179               224
#
#    Def. Zone Starts On The Fly Starts  Off. Zone Start %  Off. Zone Faceoffs  \
# ...

# %%
df.shape
# Out:
# (920, 54)

# %%
# Check to see if there are any null values for any player in the table (THERE AREN'T)
null_check = df.isnull().sum()
null_check
# Out:
# Unnamed: 0             0
# Player                 0
# Team                   0
# Position               0
# GP                     0
# TOI                    0
# CF                     0
# CA                     0
# CF%                    0
# FF                     0
# FA                     0
# FF%                    0
# SF                     0
# SA                     0
# SF%                    0
# GF                     0
# GA                     0
# GF%                    0
# xGF                    0
# xGA                    0
# xGF%                   0
# SCF                    0
# SCA                    0
# SCF%                   0
# HDCF                   0
# HDCA                   0
# HDCF%                  0
# HDGF                   0
# HDGA                   0
# HDGF%                  0
# MDCF                   0
# MDCA                   0
# MDCF%                  0
# MDGF                   0
# MDGA                   0
# MDGF%                  0
# LDCF                   0
# ...
